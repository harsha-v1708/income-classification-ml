# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('income.csv')

# %%
data.head(5)
# Out:
#    age       JobType         EdType        maritalstatus       occupation  \
# 0   45       Private        HS-grad             Divorced     Adm-clerical
# 1   24   Federal-gov        HS-grad        Never-married     Armed-Forces
# 2   44       Private   Some-college   Married-civ-spouse   Prof-specialty
# 3   27       Private            9th        Never-married     Craft-repair
# 4   20       Private   Some-college        Never-married            Sales
#
#       relationship    race   gender  capitalgain  capitalloss  hoursperweek  \
# 0    Not-in-family   White   Female            0            0            28
# 1        Own-child   White     Male            0            0            40
# 2          Husband   White     Male            0            0            40
# 3   Other-relative   White     Male            0            0            40
# 4    Not-in-family   White     Male            0            0            35
#
#     nativecountry                        SalStat
# ...

# %%
data.tail(3)
# Out:
#        age     JobType         EdType        maritalstatus       occupation  \
# 31975   23     Private   Some-college   Married-civ-spouse     Adm-clerical
# 31976   42   Local-gov   Some-college   Married-civ-spouse     Adm-clerical
# 31977   29     Private      Bachelors        Never-married   Prof-specialty
#
#          relationship    race   gender  capitalgain  capitalloss  \
# 31975         Husband   White     Male            0            0
# 31976            Wife   White   Female            0            0
# 31977   Not-in-family   White     Male            0            0
#
#        hoursperweek   nativecountry                        SalStat
# 31975            40   United-States   less than or equal to 50,000
# 31976            40   United-States   less than or equal to 50,000
# 31977            40   United-States   less than or equal to 50,000

# %%
data.shape
# Out:
# (31978, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31978 entries, 0 to 31977
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            31978 non-null  int64
#  1   JobType        31978 non-null  object
#  2   EdType         31978 non-null  object
#  3   maritalstatus  31978 non-null  object
#  4   occupation     31978 non-null  object
#  5   relationship   31978 non-null  object
#  6   race           31978 non-null  object
#  7   gender         31978 non-null  object
#  8   capitalgain    31978 non-null  int64
#  9   capitalloss    31978 non-null  int64
#  10  hoursperweek   31978 non-null  int64
#  11  nativecountry  31978 non-null  object
#  12  SalStat        31978 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 3.2+ MB

# %%
data.describe()
# Out:
#                 age   capitalgain   capitalloss  hoursperweek
# count  31978.000000  31978.000000  31978.000000  31978.000000
# mean      38.579023   1064.360623     86.739352     40.417850
# std       13.662085   7298.596271    401.594301     12.345285
# min       17.000000      0.000000      0.000000      1.000000
# 25%       28.000000      0.000000      0.000000     40.000000
# 50%       37.000000      0.000000      0.000000     40.000000
# 75%       48.000000      0.000000      0.000000     45.000000
# max       90.000000  99999.000000   4356.000000     99.000000

# %%
data.isna()
# Out:
#          age  JobType  EdType  maritalstatus  occupation  relationship   race  \
# 0      False    False   False          False       False         False  False
# 1      False    False   False          False       False         False  False
# 2      False    False   False          False       False         False  False
# 3      False    False   False          False       False         False  False
# 4      False    False   False          False       False         False  False
# ...      ...      ...     ...            ...         ...           ...    ...
# 31973  False    False   False          False       False         False  False
# 31974  False    False   False          False       False         False  False
# 31975  False    False   False          False       False         False  False
# 31976  False    False   False          False       False         False  False
# 31977  False    False   False          False       False         False  False
#
# ...

# %%
data.isna().sum()
# Out:
# age              0
# JobType          0
# EdType           0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# gender           0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# nativecountry    0
# SalStat          0
# dtype: int64

# %%
data.dtypes
# Out:
# age               int64
# JobType          object
# EdType           object
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# gender           object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# nativecountry    object
# SalStat          object
# dtype: object

# %%
data['JobType'].unique()
# Out:
# array([' Private', ' Federal-gov', ' ?', ' Self-emp-inc',
#        ' Self-emp-not-inc', ' Local-gov', ' State-gov', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
Cat_data= data.select_dtypes('object')
for i in Cat_data:
    data= data.drop(i, axis=1)

# %%
Cat_data
# Out:
#             JobType         EdType        maritalstatus        occupation  \
# 0           Private        HS-grad             Divorced      Adm-clerical
# 1       Federal-gov        HS-grad        Never-married      Armed-Forces
# 2           Private   Some-college   Married-civ-spouse    Prof-specialty
# 3           Private            9th        Never-married      Craft-repair
# 4           Private   Some-college        Never-married             Sales
# ...             ...            ...                  ...               ...
# 31973     Local-gov        HS-grad        Never-married   Farming-fishing
# 31974     Local-gov   Some-college        Never-married   Protective-serv
# 31975       Private   Some-college   Married-civ-spouse      Adm-clerical
# 31976     Local-gov   Some-college   Married-civ-spouse      Adm-clerical
# 31977       Private      Bachelors        Never-married    Prof-specialty
#
#           relationship    race   gender   nativecountry  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for i in Cat_data:
    Cat_data[i] = label_encoder.fit_transform(Cat_data[i])

# %%
data
# Out:
#        age  capitalgain  capitalloss  hoursperweek
# 0       45            0            0            28
# 1       24            0            0            40
# 2       44            0            0            40
# 3       27            0            0            40
# 4       20            0            0            35
# ...    ...          ...          ...           ...
# 31973   34          594            0            60
# 31974   34            0            0            40
# 31975   23            0            0            40
# 31976   42            0            0            40
# 31977   29            0            0            40
#
# [31978 rows x 4 columns]

# %%
Cat_data
# Out:
#        JobType  EdType  maritalstatus  occupation  relationship  race  gender  \
# 0            4      11              0           1             1     4       0
# 1            1      11              4           2             3     4       1
# 2            4      15              2          10             0     4       1
# 3            4       6              4           3             2     4       1
# 4            4      15              4          12             1     4       1
# ...        ...     ...            ...         ...           ...   ...     ...
# 31973        2      11              4           5             1     2       1
# 31974        2      15              4          11             1     4       0
# 31975        4      15              2           1             0     4       1
# 31976        2      15              2           1             5     4       0
# 31977        4       9              4          10             1     4       1
#
#        nativecountry  SalStat
# ...

# %%
df = pd.concat([data,Cat_data],axis=1)

# %%
df
# Out:
#        age  capitalgain  capitalloss  hoursperweek  JobType  EdType  \
# 0       45            0            0            28        4      11
# 1       24            0            0            40        1      11
# 2       44            0            0            40        4      15
# 3       27            0            0            40        4       6
# 4       20            0            0            35        4      15
# ...    ...          ...          ...           ...      ...     ...
# 31973   34          594            0            60        2      11
# 31974   34            0            0            40        2      15
# 31975   23            0            0            40        4      15
# 31976   42            0            0            40        2      15
# 31977   29            0            0            40        4       9
#
#        maritalstatus  occupation  relationship  race  gender  nativecountry  \
# ...

# %% [markdown]
# # Visualization

# %%
Income_by_gender = df.groupby('gender')['SalStat'].sum().sort_values(ascending=False)

# %%
Income_by_gender
# Out:
# gender
# 1    14837
# 0     9446
# Name: SalStat, dtype: int32

# %%
plt.figure(figsize=(5, 4))  
sns.barplot(x=Income_by_gender.index, y=Income_by_gender.values)
plt.xlabel('Gender')
plt.ylabel('SalStat')
plt.title('Distribution of Salary by Gender')  
plt.show()

# %%
Income_by_age = df.groupby('age')['SalStat'].sum().sort_values(ascending=False)

# %%
Income_by_age
# Out:
# age
# 23    859
# 25    777
# 24    753
# 20    743
# 22    741
#      ...
# 83      4
# 85      3
# 88      3
# 86      1
# 87      1
# Name: SalStat, Length: 73, dtype: int32

# %%
plt.figure(figsize=(8, 5))  
sns.histplot(x=Income_by_age.index, y=Income_by_age.values, bins=20, kde=True)
plt.xlabel('Age')
plt.ylabel('SalStat')
plt.title('Distribution of Salary by Age')  
plt.grid(True)
plt.show()

# %%
Income_by_JobType = df.groupby('JobType')['SalStat'].sum().sort_values(ascending=False)

# %%
Income_by_JobType
# Out:
# JobType
# 4    17410
# 6     1785
# 0     1622
# 2     1458
# 7      935
# 1      578
# 5      474
# 8       14
# 3        7
# Name: SalStat, dtype: int32

# %%
plt.figure(figsize=(8, 5))  
sns.histplot(x=Income_by_JobType.index, y=Income_by_JobType.values, bins=20, kde=True)
plt.xlabel('JobType')
plt.ylabel('SalStat')
plt.title('Distribution of Salary by JobType')  
plt.grid(True)
plt.show()

# %%
df['JobType'].unique()
# [' Private', ' Federal-gov', ' ?', ' Self-emp-inc',' Self-emp-not-inc', ' Local-gov', ' State-gov', ' Without-pay',' Never-worked']
# Out:
# array([4, 1, 0, 5, 6, 2, 7, 8, 3])

# %% [markdown]
# # Ml Model Building

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
Y= df['SalStat']
X= df.drop(['SalStat'],axis=1)

# %%
imp_df=pd.DataFrame(mutual_info_classif(X,Y), index=X.columns)

# %%
imp_df.to_csv('imp_df')
a=pd.read_csv('imp_df')
a
# Out:
#        Unnamed: 0         0
# 0             age  0.055826
# 1     capitalgain  0.052424
# 2     capitalloss  0.010046
# 3    hoursperweek  0.035895
# 4         JobType  0.009289
# 5          EdType  0.011123
# 6   maritalstatus  0.107187
# 7      occupation  0.032200
# 8    relationship  0.064338
# 9            race  0.008135
# 10         gender  0.031079
# 11  nativecountry  0.009406

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
alg=RandomForestClassifier()
alg.fit(X_train, y_train)
y_pred=alg.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8522514071294559

# %%
plt.figure(figsize=(4, 4))
plt.bar(["accuracy"], [accuracy], color='orange')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.show()

# %% [markdown]
# #
